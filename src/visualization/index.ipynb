# %% [markdown]
# ## 2.2. Asking meaningful questions that need to be answered
# &#9889; This notebook present for each questions:
# 1. What is the question?
# 2. What are benefits of finding the answer?
# 3. How to find the answers of questions by using data

# %% [markdown]
# ## Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read the data from the csv file and store it in a dataframe

# %%
df_products = pd.read_csv('../../data/raw/products_detail.csv')
df_products.head()
# Out:
#         p_id                                             p_name  p_id_shop  \
# 0   83412126  Bình Giữ Nhiệt Lock&Lock Energetic One-Touch T...    38510.0
# 1   53789448  Bộ cây lau nhà tự vắt thông minh, chổi lau nhà...    96639.0
# 2  212830295                          ( hàng sẵn )squyshi to bự   318926.0
# 3   13334313  Bộ 6 chén (bát) cơm sứ phong cách Nhật Bản hoa...     3340.0
# 4   99868980  Bình Giữ Nhiệt Locknlock Bucket Tumbler LHC426...        1.0
#
#                     p_shop_name    p_brand        p_categories  p_day_created  \
# 0  JoyMall LocknLock Chính Hãng  LocknLock      Bình giữ nhiệt          659.0
# 1                 Parroti Store    Parroti  Nhà Cửa - Đời Sống          974.0
# 2                       Squishy        OEM                Root            8.0
# 3  Công ty TNHH TM Minh Gia Lợi        OEM  Nhà Cửa - Đời Sống         1372.0
# 4                  Tiki Trading  LocknLock      Bình giữ nhiệt          593.0
#
#    p_sold_quantity  p_original_price  p_current_price  p_discount_rate
# 0              702            528000           269000               49
# 1            12844            799000           429000               46
# 2                0             59000            59000                0
# 3              938            209000           209000                0
# 4            10359            473000           235000               50

# %% [markdown]
# # <font color="green"><b>Question 1:</b></font>

# %% [markdown]
# ## 2.2.1. What is the question?
# &#9889; Which store is the best seller and which item is the best seller in category is the best seller? And why is it the best seller?

# %% [markdown]
# ## 2.2.2. What are benefits of finding the answer?
# &#9889; The answer of this question will help the company to know which store is the best seller and which item is the best seller in category is the best seller. And why is it the best seller? The company can use this information to improve the business. And check out strategies to improve the business and increase the sales.

# %% [markdown]
# ## 2.2.3. How to find the answers of questions by using data?
# 1. The first step is find category is the best seller.
# 2. The third step is find store is the best seller.
# 3. The second step is find item is the best seller in category is the best seller.

# %% [markdown]
# #### 1. The first step is find category is the best seller.

# %%
df_cate_best_seller = df_products['p_categories'].value_counts().sort_values(ascending=False).index[0]
df_cate_best_seller = df_products[df_products['p_categories'] == df_cate_best_seller]
df_cate_best_seller.head()
# Out:
#        p_id                                             p_name  p_id_shop  \
# 1  53789448  Bộ cây lau nhà tự vắt thông minh, chổi lau nhà...    96639.0
# 3  13334313  Bộ 6 chén (bát) cơm sứ phong cách Nhật Bản hoa...     3340.0
# 7  73124602  Bình Giữ Nhiệt Bằng Thép Không Gỉ Lock&Lock Va...    38510.0
# 8  72652203  Hộp đựng thức ăn cho bé Lock&Lock có vạch chia...        1.0
# 9  21441057                  Chảo Chống Dính Đá Sunhouse SBD18   182530.0
#
#                     p_shop_name    p_brand        p_categories  p_day_created  \
# 1                 Parroti Store    Parroti  Nhà Cửa - Đời Sống          974.0
# 3  Công ty TNHH TM Minh Gia Lợi        OEM  Nhà Cửa - Đời Sống         1372.0
# 7  JoyMall LocknLock Chính Hãng  LocknLock  Nhà Cửa - Đời Sống          775.0
# 8                  Tiki Trading  LocknLock  Nhà Cửa - Đời Sống          785.0
# 9              GIADUNG TẤN PHÁT   Sunhouse  Nhà Cửa - Đời Sống         1280.0
#
#    p_sold_quantity  p_original_price  p_current_price  p_discount_rate
# 1            12844            799000           429000               46
# 3              938            209000           209000                0
# 7             1437            677000           349000               48
# 8            11686            350000           170000               51
# 9                3            182900           182900                0

# %% [markdown]
# #### 2. The third step is find store is the best seller.

# %%
df_shop_best_seller = df_cate_best_seller['p_id_shop'].value_counts().sort_values(ascending=False).index[0]
df_shop_best_seller = df_cate_best_seller[df_cate_best_seller['p_id_shop'] == df_shop_best_seller]
df_shop_best_seller.head()
# Out:
#         p_id                                             p_name  p_id_shop  \
# 8   72652203  Hộp đựng thức ăn cho bé Lock&Lock có vạch chia...        1.0
# 18   3480627  Bộ Cây Lau Nhà Xoay Tay Compact Spin Mop Lock&...        1.0
# 28  53583472  Bộ Hộp Cơm Giữ Nhiệt Lock&Lock Easy Carry 2L L...        1.0
# 37   1657931                  Vợt Muỗi Sunhouse SHE-E200 - Vàng        1.0
# 75  10227148  Dụng Cụ Mài Dao 3 Lớp Lock&Lock CKK112 (245 x ...        1.0
#
#      p_shop_name    p_brand        p_categories  p_day_created  \
# 8   Tiki Trading  LocknLock  Nhà Cửa - Đời Sống          785.0
# 18  Tiki Trading  LocknLock  Nhà Cửa - Đời Sống         1616.0
# 28  Tiki Trading  LocknLock  Nhà Cửa - Đời Sống          981.0
# 37  Tiki Trading   Sunhouse  Nhà Cửa - Đời Sống         1755.0
# 75  Tiki Trading  LocknLock  Nhà Cửa - Đời Sống         1442.0
#
#     p_sold_quantity  p_original_price  p_current_price  p_discount_rate
# 8             11686            350000           170000               51
# 18             6621            924000           475000               49
# 28             9861           1667000           790000               53
# 37             8816            119000            74000               38
# 75             2690            275000           137000               50

# %% [markdown]
# #### 3. The second step is find item is the best seller in category is the best seller.

# %%
# get top 10 products in best seller shop in best seller category 
df_top5_products = df_shop_best_seller.sort_values(by='p_sold_quantity', ascending=False)
df_top5_products.head(10)
# Out:
#           p_id                                             p_name  p_id_shop  \
# 501     466737               Hộp Hâm Nóng Life360 EL-ALS263 (Tím)        1.0
# 97     1575707  Bình Giữ Nhiệt Lock&Lock New Basic Table LHC40...        1.0
# 1305   1024190  Bộ 3 Hộp Cơm Giữ Nhiệt Lock&Lock Mushroom LHC8...        1.0
# 8     72652203  Hộp đựng thức ăn cho bé Lock&Lock có vạch chia...        1.0
# 137    1399571  Gối Memory Foam 50D Hình Cong Lock&Lock HLW111...        1.0
# 28    53583472  Bộ Hộp Cơm Giữ Nhiệt Lock&Lock Easy Carry 2L L...        1.0
# 37     1657931                  Vợt Muỗi Sunhouse SHE-E200 - Vàng        1.0
# 184     578967    Chảo Đá Chống Dính Siêu Bền Sunhouse SBD28 28cm        1.0
# 1904   4630783  Ly Giữ Nhiệt Bằng Thép Không Gỉ Lock&Lock Clip...        1.0
# 18     3480627  Bộ Cây Lau Nhà Xoay Tay Compact Spin Mop Lock&...        1.0
#
#        p_shop_name    p_brand        p_categories  p_day_created  \
# 501   Tiki Trading    Life360  Nhà Cửa - Đời Sống         2093.0
# 97    Tiki Trading  LocknLock  Nhà Cửa - Đời Sống         1768.0
# 1305  Tiki Trading  LocknLock  Nhà Cửa - Đời Sống         1909.0
# 8     Tiki Trading  LocknLock  Nhà Cửa - Đời Sống          785.0
# 137   Tiki Trading  LocknLock  Nhà Cửa - Đời Sống         1804.0
# 28    Tiki Trading  LocknLock  Nhà Cửa - Đời Sống          981.0
# 37    Tiki Trading   Sunhouse  Nhà Cửa - Đời Sống         1755.0
# 184   Tiki Trading   Sunhouse  Nhà Cửa - Đời Sống         2132.0
# 1904  Tiki Trading  LocknLock  Nhà Cửa - Đời Sống         1570.0
# 18    Tiki Trading  LocknLock  Nhà Cửa - Đời Sống         1616.0
#
#       p_sold_quantity  p_original_price  p_current_price  p_discount_rate
# 501             23009            799000           433000               46
# 97              20875            424000           206000               51
# 1305            18192           1007000           473000               53
# 8               11686            350000           170000               51
# 137             10395            483000           240000               50
# 28               9861           1667000           790000               53
# 37               8816            119000            74000               38
# 184              8162            430000           267000               38
# 1904             7702            506000           250000               51
# 18               6621            924000           475000               49

# %% [markdown]
# &#9889; <font color="yellow"><b>Conclusion:</b></font> The best seller category is "Nhà Cửa - Đời Sống" and the best seller store is "Tiki Trading" and the best seller item is "Hộp Hâm Nóng Life360 EL-ALS263 (Tím)" in category is the best seller. And the reason is the price of the item is low, discount is high, the number of orders is high (Buyer psychology will choose products with a large number of purchases to choose to buy), the quality of the item is good, brand of the item is famous (Life360, LocknLock,...), strategy advertising of the item is good.
